# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\HP\Downloads\iris.csv")

# %%
df.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.tail(5)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
df.shape
# Out:
# (150, 5)

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='str')

# %%
df.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species             str
# dtype: object

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df["species"].unique()
# Out:
# <StringArray>
# ['setosa', 'versicolor', 'virginica']
# Length: 3, dtype: str

# %%
df["species"].value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
print("Mean - " ,round( df["sepal_length"].mean(),4))
print("Mean - " , round(df["sepal_width"].mean(),3))
print("Mean - " ,round( df["petal_length"].mean(),4))
print("Mean - " ,round( df["petal_width"].mean(),4))
# Out:
# Mean -  5.8433
# Mean -  3.054
# Mean -  3.7587
# Mean -  1.1987

# %%
print("Maximum sepal_length- " ,df["sepal_length"].max())
print("Maximum sepal_width- " ,df["sepal_width"].max())
print("Maximum petal_length- " ,df["petal_length"].max())
print("Maximum sepal_width- " ,df["petal_width"].max())
# Out:
# Maximum sepal_length-  7.9
# Maximum sepal_width-  4.4
# Maximum petal_length-  6.9
# Maximum sepal_width-  2.5

# %%
print("Minimum sepal_length- ",df["sepal_length"].min())
print("Minimum sepal_width- ",df["sepal_width"].min())
print("Minimum petal_lengt- ",df["petal_length"].min())
print("Minimum petal_width- ",df["petal_width"].min())
# Out:
# Minimum sepal_length-  4.3
# Minimum sepal_width-  2.0
# Minimum petal_lengt-  1.0
# Minimum petal_width-  0.1

# %%
print("Standard devaition - " , round(df["sepal_length"].std(),4))
print("Standard devaition - " , round(df["sepal_width"].std(),4))
print("Standard devaition - " ,round( df["petal_length"].std(),4))
print("Standard devaition - " ,round( df["petal_width"].std(),4))
# Out:
# Standard devaition -  0.8281
# Standard devaition -  0.4336
# Standard devaition -  1.7644
# Standard devaition -  0.7632

# %%
df.groupby("species")["sepal_length"].mean()
df.groupby("species")["sepal_width"].mean()
df.groupby("species")["petal_length"].mean()
df.groupby("species")["petal_width"].mean()
# Out:
# species
# setosa        0.244
# versicolor    1.326
# virginica     2.026
# Name: petal_width, dtype: float64

# %%
plt.scatter(df["sepal_length"],df["sepal_width"] , c = "red")
plt.xlabel("sepal_length")
plt.ylabel("sepal_width")
plt.show()

# %%
plt.scatter(df["petal_length"],df["petal_width"] , c = "red")
plt.xlabel("petal_length")
plt.ylabel("petal_width")
plt.show()

# %%
plt.hist(df["sepal_length"] ,bins = 10 , edgecolor="black")
plt.show()

# %%
plt.hist(df["sepal_width"] ,bins = 10 , edgecolor="black")
plt.show()

# %%
plt.hist(df["petal_length"] ,bins = 10 , edgecolor="black")
plt.show()

# %%
plt.hist(df["petal_width"] ,bins = 10 , edgecolor="black")
plt.show()
